# %% [markdown]
# <a href="https://colab.research.google.com/github/fredprada/Dex_Course_FredericoPrada/blob/main/aula_Repeti%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #REPETIÇÕES <br>

# %% [markdown]
# ## Primeira aula

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range (1,7,1):
  print('o número é {}'.format(i))
print('☻')
# Out:
# o número é 1
# o número é 2
# o número é 3
# o número é 4
# o número é 5
# o número é 6
# ☻

# %%
soma = 0
for i in range (1,9+1,2):
  soma = soma + i
  print('i = {} e soma = {}'.format(i,soma))
print('soma = {}'.format(soma))
# Out:
# i = 1 e soma = 1
# i = 3 e soma = 4
# i = 5 e soma = 9
# i = 7 e soma = 16
# i = 9 e soma = 25
# soma = 25

# %%
soma = 0
for i in range (1, 3+1):
  n = int(input('digite um numero: '))
  soma = soma + n
  print('n = {} e soma = {}'.format(n,soma))
print('soma = {}'.format(soma))
# Out:
# digite um numero: 1
# n = 1 e soma = 1
# digite um numero: 5
# n = 5 e soma = 6
# digite um numero: 4
# n = 4 e soma = 10
# soma = 10

# %% [markdown]
# ### Cálculos incrementais

# %%
soma = 10
# soma = soma + 1
soma += 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### WHILE

# %%
fim = 'não'
while fim == 'não':
  print('ler pg')
  fim = input('você terminou?')
print('fim')
# Out:
# ler pg
# você terminou?não
# ler pg
# você terminou?não
# ler pg
# você terminou?não
# ler pg
# você terminou?aaa
# fim

# %%
# digite numeros quaisquer até que a soma ultrapasse 20

soma = 0

while soma < 20:
  n = float(input('digite um numero: '))
  soma += n
print('a soma final foi de {:.2f}'.format(soma))
# Out:
# digite um numero: 5
# digite um numero: -8
# digite um numero: 9
# digite um numero: -70
# digite um numero: 100
# a soma final foi de 36.00

# %% [markdown]
# #### break

# %%
soma = 0
while True:
  n = float(input('aaa'))
  soma += n
  continua = input('continua? (s/n)')
  if continua == 'n':
    break
print(soma)
# Out:
# aaa5
# continua?s
# aaa20
# continua?s
# aaa60
# continua?n
# 85.0
