# %% [markdown]
# <a href="https://colab.research.google.com/github/fredprada/Dex_Course_FredericoPrada/blob/main/operacoes_em_python_operadores_aritmericos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Operadores Aritméricos

# %%
print(7+9)
# Out:
# 16

# %%
print(7**9)
# Out:
# 40353607

# %%
print(9//4) # retorna a divisão inteira
print(9/4) # retorna a divisão com vírgula
print(9%4) # retorna o resto
# Out:
# 2
# 2.25
# 1

# %%
# * e + funcionam com strings
print('Olá' + ' mundo')
print('Olá '*5)
# Out:
# Olá mundo
# Olá Olá Olá Olá Olá

# %%
print('-'*21)
print(' '*6+'bem vindo'+' '*6)
print('-'*21)
# Out:
# ---------------------
#       bem vindo
# ---------------------

# %% [markdown]
# ### Ordem de precedência: <br>
# * ( )
# * " ** "
# * " * " / % //
# * " + " -

# %% [markdown]
# ### Transformando variáveis
# int () <br>
# float () <br>
# str () <br>
# vamos usar sempre após o input () (porque ele retorna como str)

# %%
int(1.857)
# Out:
# 1

# %%
int('4')
# Out:
# 4

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
float(1)
# Out:
# 1.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('4')
# Out:
# 4.0

# %%
str(1)
# Out:
# '1'

# %%
str(.2758)
# Out:
# '0.2758'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %% [markdown]
# ## PRINT COM FORMAT

# %%
a = 2

# %%
b = 3

# %%
print('text {}, mais texto {}'.format(a,b))
# Out:
# text 2, mais texto 3

# %%
a = 1
b = 7
print('a dividido por b é: {}'.format(a/b))
# Out:
# a dividido por b é: 0.14285714285714285

# %%
a = 245
b = 2.835895
print('{0:10d} e {1:10.2f}'.format(a,b))
# Out:
#        245 e       2.84

# %% [markdown]
# ![image.png](data:image/png;base64,...)
